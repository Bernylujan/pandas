# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("DatosEstand.csv")
data
# Out:
#          fecha  tasaInteres    volume     close  adjClose
# 0     1/1/2005     1.562915 -1.858385 -2.003563 -2.003563
# 1     2/1/2005     1.830819 -1.796631 -1.931411 -1.931411
# 2     3/1/2005     1.957464 -2.050070 -2.047356 -2.047356
# 3     4/1/2005     2.064625 -1.986897 -2.084239 -2.084239
# 4     5/1/2005     2.123076 -1.801460 -2.017396 -2.017396
# ..         ...          ...       ...       ...       ...
# 127   8/1/2015    -1.145341  0.628636  1.187995  1.187995
# 128   9/1/2015    -1.116115  0.261060  1.074461  1.074461
# 129  10/1/2015    -1.155083  0.553772  1.273535  1.273535
# 130  11/1/2015    -1.155083  0.510891  1.156375  1.156375
# 131  12/1/2015    -1.096631  0.703087  1.110411  1.110411
#
# [132 rows x 5 columns]

# %%
plt.scatter(data["tasaInteres"],data["volume"])
plt.xlabel("Tasa de Interes")
plt.ylabel("Volumen de Operaciones")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(data["tasaInteres"],data["close"])
plt.xlabel("Tasa de Interes")
plt.ylabel("Cierre de Cotizaciones")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(data["tasaInteres"],data["adjClose"])
plt.xlabel("Tasa de Interes")
plt.ylabel("Cierre Ajustado de Cotizaciones")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.corr()
# Out:
#              tasaInteres    volume     close  adjClose
# tasaInteres     1.000000 -0.683132 -0.907605 -0.907605
# volume         -0.683132  1.000000  0.669907  0.669907
# close          -0.907605  0.669907  1.000000  1.000000
# adjClose       -0.907605  0.669907  1.000000  1.000000
